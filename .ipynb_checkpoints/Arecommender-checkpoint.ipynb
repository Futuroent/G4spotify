# %%
import config
import spotipy
import pandas as pd
import json
import pprint
from spotipy.oauth2 import SpotifyClientCredentials
import pickle
from sklearn.cluster import KMeans


#Initialize SpotiPy with user credentials

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %%
#LOAD TRAINED MODEL

import pickle

# Load the model
with open('spotify_kmeans_model.pkl', 'rb') as file:
    kmeans_model = pickle.load(file)

# %%
#LOAD DATABASE

df5k2 = pd.read_csv("Data/Clean/df5k2.csv")
df5k2
# Out:
#       Unnamed: 0  danceability  energy  loudness  speechiness  acousticness  \
# 0              0         0.513   0.868    -5.061       0.0410       0.01850
# 1              1         0.646   0.359   -10.388       0.1550       0.24700
# 2              2         0.825   0.652    -3.183       0.0802       0.58100
# 3              3         0.694   0.770    -5.335       0.1490       0.17600
# 4              4         0.730   0.769    -5.114       0.0298       0.13800
# ...          ...           ...     ...       ...          ...           ...
# 4630        4630         0.719   0.580    -6.173       0.0903       0.08180
# 4631        4631         0.449   0.585    -6.761       0.0268       0.05090
# 4632        4632         0.690   0.723    -9.204       0.0639       0.17400
# 4633        4633         0.626   0.674   -10.002       0.0411       0.00237
# 4634        4634         0.795   0.714    -9.901       0.0682       0.02120
#
#       instrumentalness  liveness  valence    tempo  duration_ms  cluster  \
# 0             0.000000    0.1210   0.3670   92.009       230467        1
# 1             0.914000    0.0872   0.1540  119.885       360147        2
# 2             0.000000    0.0931   0.9310   95.977       233713        1
# 3             0.000011    0.1180   0.1630  125.905       184560        0
# 4             0.000000    0.0473   0.5070  104.948       228093        1
# ...                ...       ...      ...      ...          ...      ...
# 4630          0.812000    0.1170   0.4900  170.099       131294        0
# 4631          0.000087    0.0833   0.2120  139.631       278719        1
# 4632          0.000000    0.2550   0.4870  149.987       157192        0
# 4633          0.863000    0.1060   0.0489  124.977       375361        2
# 4634          0.009520    0.1170   0.6430  124.007       234320        1
#
#                           id                             names
# 0     1VU8t2MpJRLG5iFEIxqq7z               Geboren um zu leben
# 1     4YRvb9B8cgvhst11qk8CKn                        Sonnentanz
# 2     7qiZfU4dY1lWllzX7mPBI3                      Shape of You
# 3     0E9ZjEAyAwOXZ7wJC0PD33                        In My Mind
# 4     4OSBTYWVwsQhGLF9NHvIbR               Rolling in the Deep
# ...                      ...                               ...
# 4630  1Wl0fMRT0YzndDmHZCFvoT                          Roadtrip
# 4631  6DGIg7YNSXWz1SAnJ1S8bX                          Paradise
# 4632  6WzGciwEdqlkPuMf3bDmX7                          Roadtrip
# 4633  2IJZWPp6TnMWHyGqjrz3Ci  Roadtrip - Moritz Hofbauer Remix
# 4634  4IcdIxyxy24MWhy8TgGCQE                         Road Trip
#
# [4635 rows x 14 columns]

# %%
song_name = input("Write the song:") #GET USER INPUT
# Out:
# Write the song: love

# %%
def bring_song (song_name):
    result = sp.search(q=song_name, limit=1, market ="ES") #SEARCH FOR THE RESULT
    id = result["tracks"]["items"][0]["id"] #BRING THE ID
    return id

# %%
def classify_song (id):
    features = sp.audio_features(id) #BRING ALL FEATURES
    X=pd.DataFrame(features) #TURN ARRAY INTO DATAFRAME
    X=X[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]] #CHANGE THE COLUMN NAMES
    X = X.drop("id", axis=1) #DROP ID
    cluster = kmeans_model.predict(X) #RUN PREDICTION 
    cluster = cluster[0] #CHANGE ARRAY TO NUMBER
    return cluster

# %%
def song_recomender (cluster):
    same_cluster_songs = df.loc[df['cluster'] == cluster] #SEARCH FOR ALL THE SONGS WITH THE SAME CLUSTER
    random_sample = same_cluster_songs.sample(n=1) #SELECT RANDOMLY 1 SONG 
    return random_sample

# %%
song_id = bring_song (song_name)

# %%
cluster = classify_song(song_id)

# %%
song = song_recomender(cluster)
song
